# %% [markdown]
# **3. LSVT**
# ---

# %%
### Basic Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.io import loadmat

### Classifiers
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier


#### Datasets, Metrics and Preprocessing

from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, cross_val_predict, cross_validate
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

from sklearn.utils.multiclass import unique_labels

# %%
# import classiy function from the 'main_functions' notebook
from ipynb.fs.defs.main_functions import classify, plot_confusion, del_nan

# %%
# Defining the classifier that can be used with easy calling names
classifiers = {'Naive Bayes': GaussianNB, 'KNN': KNeighborsClassifier, 'Logistic Regression': LogisticRegression,\
              'RF': RandomForestClassifier, 'SVM': SVC, 'SGD': SGDClassifier, 'AdaBoost': AdaBoostClassifier}

# %%
# Reading the dataset and creating the dataframe
image = loadmat('Datasets.mat/TsanasLSVT.mat')

df = pd.DataFrame(image.get('X'))
df['y'] = image.get('y').ravel()

# %%
X,y, nb_del = del_nan(df.drop('y',axis=1),df['y'])

df = pd.DataFrame(X)
df['y'] = y
print('Number of deleted rows is %d'%nb_del)
# Out:
# Number of deleted rows is 0

# %%
df, df_test = train_test_split(df, test_size=0.2, stratify=df['y'])

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# This step is to get to know the data and decide what type of preprocessing needs to be done before training the model

# %%
df.head()
# Out:
#             0         1         2         3         4         5             6  \
# 54   0.055473  0.017125  0.000196 -0.000004  0.000193  0.996306  1.017477e-07
# 5    0.224738  0.122597  0.001437  0.000003  0.000932  2.787218  3.076854e-06
# 117  0.039467  0.025455  0.000288  0.000004  0.000322  0.819314  4.153631e-07
# 75   0.273794  0.226380  0.002594  0.000080  0.002136  1.502639  1.128910e-04
# 17   0.152850  0.063486  0.000749 -0.000005  0.000381  2.178093  7.712164e-07
#
#               7            8          9 ...       301        302        303  \
# 54   106.171564  3193.960892  -9.468112 ...  8.323533  23.185868  63.649792
# 5     51.817177  1113.744107 -36.569114 ...  6.795204  18.941736  52.039946
# 117   26.233326   782.551838  -2.650014 ...  6.324716  17.625236  48.503639
# 75    68.147013  1553.674918 -15.970537 ...  6.650108  19.278384  53.180511
# 17    66.510843  1772.750843 -22.447775 ...  7.489785  20.862609  57.269902
#
#             304         305          306          307          308  \
# 54   170.552682  439.295937  1080.760424  2506.743051  5510.931862
# 5    139.465979  359.217612   882.761062  2044.991935  4496.777621
# 117  129.927666  334.506098   822.375997  1907.030279  4193.418113
# 75   140.491249  360.053593   903.207527  2099.364810  4593.160240
# 17   153.456286  395.249699   971.107524  2253.100969  4955.016058
#
#               309  y
# 54   11641.303193  1
# 5     9504.445938  3
# 117   8863.314090  1
# 75    9667.960558  1
# 17   10474.210361  3
#
# [5 rows x 311 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 54 to 6
# Columns: 311 entries, 0 to y
# dtypes: float64(310), uint8(1)
# memory usage: 243.1 KB

# %%
df.describe()
# Out:
#                 0           1           2             3           4  \
# count  100.000000  100.000000  100.000000  1.000000e+02  100.000000
# mean     0.202562    0.108361    0.001261  9.859359e-08    0.000946
# std      0.297914    0.163650    0.001934  1.602529e-05    0.001662
# min      0.020443    0.013830    0.000159 -3.532258e-05    0.000060
# 25%      0.055185    0.027003    0.000301 -5.099300e-06    0.000244
# 50%      0.094033    0.044692    0.000480 -2.050570e-06    0.000377
# 75%      0.183513    0.123047    0.001443  2.128356e-06    0.000979
# max      1.981593    0.829645    0.009845  9.082689e-05    0.010443
#
#                 5             6           7             8           9  \
# count  100.000000  1.000000e+02  100.000000    100.000000  100.000000
# mean     5.808890  1.214412e-04   76.709077   1749.069414  -34.168956
# std     22.748573  8.116484e-04  102.382629   1657.716717   80.809640
# min      0.548917  7.679846e-08   13.319091    327.451852 -547.417983
# 25%      1.088000  3.713828e-07   29.987587    800.267467  -20.227969
# 50%      1.907548  7.626807e-07   51.960514   1356.767272   -8.693944
# 75%      3.199981  8.796069e-06   83.876000   2024.316305   -3.895480
# max    218.686963  7.890252e-03  906.320483  12299.065627   -0.603839
#
#           ...             301         302         303         304         305  \
# count     ...      100.000000  100.000000  100.000000  100.000000  100.000000
# mean      ...        7.018026   19.575498   53.752059  143.966012  371.141970
# std       ...        1.012786    2.798196    7.670634   20.408016   52.742359
# min       ...        4.982477   13.914344   38.394547  103.466808  264.654626
# 25%       ...        6.235218   17.574379   48.341910  129.357446  332.616823
# 50%       ...        6.942224   19.302296   53.133665  141.364640  366.706743
# 75%       ...        7.575389   21.100260   57.952341  155.254704  399.888702
# max       ...        9.705655   26.997531   73.998459  198.333548  510.827346
#
#                306          307          308           309           y
# count   100.000000   100.000000   100.000000    100.000000  100.000000
# mean    913.689282  2118.969971  4660.414920   9838.369014    1.990000
# std     129.122442   295.502168   643.557753   1334.344098    0.822598
# min     649.657090  1507.384591  3315.804236   6974.600636    1.000000
# 25%     819.829414  1883.220766  4140.664164   8835.911780    1.000000
# 50%     902.870861  2096.309958  4597.088099   9749.792832    2.000000
# 75%     984.328493  2282.104977  5016.846086  10598.547196    3.000000
# max    1257.014110  2916.248441  6406.074011  13537.402516    3.000000
#
# [8 rows x 311 columns]

# %%
df.hist(bins= 50, figsize=(20,20))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-746288b00fb0> in <module>()
# ----> 1 df.hist(bins= 50, figsize=(20,20))
#       2 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2411     for i, col in enumerate(com._try_sort(data.columns)):
#    2412         ax = _axes[i]
# -> 2413         ax.hist(data[col].dropna().values, bins=bins, **kwds)
#    2414         ax.set_title(col)
#    2415         ax.grid(grid)
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6665                 patch = _barfunc(bins[:-1]+boffset, height, width,
#    6666                                  align='center', log=log,
# -> 6667                                  color=c, **{bottom_kwarg: bottom})
#    6668                 patches.append(patch)
#    6669                 if stacked:
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2302             elif orientation == 'horizontal':
#    2303                 r.sticky_edges.x.append(l)
# -> 2304             self.add_patch(r)
#    2305             patches.append(r)
#    2306
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\axes\_base.py in add_patch(self, p)
#    1967         self._set_artist_props(p)
#    1968         if p.get_clip_path() is None:
# -> 1969             p.set_clip_path(self.patch)
#    1970         self._update_patch_limits(p)
#    1971         self.patches.append(p)
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     684             if isinstance(path, Rectangle):
#     685                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 686                                                path.get_transform())
#     687                 self._clippath = None
#     688                 success = True
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\patches.py in get_transform(self)
#     194         to the :class:`Patch`.
#     195         """
# --> 196         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     197
#     198     def get_data_transform(self):
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\patches.py in get_patch_transform(self)
#     707
#     708     def get_patch_transform(self):
# --> 709         self._update_patch_transform()
#     710         return self._rect_transform
#     711
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\patches.py in _update_patch_transform(self)
#     686         bbox = transforms.Bbox.from_extents(x0, y0, x1, y1)
#     687         rot_trans = transforms.Affine2D()
# --> 688         rot_trans.rotate_deg_around(x0, y0, self.angle)
#     689         self._rect_transform = transforms.BboxTransformTo(bbox)
#     690         self._rect_transform += rot_trans
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\transforms.py in rotate_deg_around(self, x, y, degrees)
#    2009         # Cast to float to avoid wraparound issues with uint8's
#    2010         x, y = float(x), float(y)
# -> 2011         return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#    2012
#    2013     def translate(self, tx, ty):
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\transforms.py in translate(self, tx, ty)
#    2021         translate_mtx = np.array(
#    2022             [[1.0, 0.0, tx], [0.0, 1.0, ty], [0.0, 0.0, 1.0]], float)
# -> 2023         self._mtx = np.dot(translate_mtx, self._mtx)
#    2024         self.invalidate()
#    2025         return self
#
# KeyboardInterrupt:

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
# top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(corrmat,annot=True,cmap="RdYlGn")

# %%
corrmat['y'].sort_values(ascending=True)

# %%
import seaborn as sns
sns.set(font_scale=2)
sns.pairplot(df, hue='y')

# %%
df['y'].value_counts()
df['y'].value_counts()/df['y'].value_counts().sum()
# print(ratio)
# Out:
# 3    0.34
# 2    0.33
# 1    0.33
# Name: y, dtype: float64

# %% [markdown]
# # Preprocessing

# %% [markdown]
# **In this dataset:** <br>
# - No categorical attributes exists <br>
# - I did not consider it as imbalanced since the ratio is almost 2:3
# - Scaling will be applied

# %%
scaler = MinMaxScaler()
df_features = df.drop('y',axis=1)
cancer_prepared = scaler.fit_transform(df_features)

# %% [markdown]
# # 1. Naive Bayes

# %%
sns.set(font_scale=1)
sns.set_style('ticks')

# %%
val_conf_NB, val_scores_NB, val_time_NB = classify(df.drop('y',axis=1), df['y'], classifiers['Naive Bayes']())
print('The average training time is %0.6f seconds'%val_time_NB.mean())
# Out:
# The model score is 0.495 (+/- 0.168)
# The IQR is 0.139 between [0.42,0.56]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.42      0.85      0.57       330
#          2.0       0.60      0.45      0.52       330
#          3.0       0.78      0.21      0.33       340
#
#     accuracy                           0.50      1000
#    macro avg       0.60      0.50      0.47      1000
# weighted avg       0.60      0.50      0.47      1000
#
# The average training time is 0.002235 seconds

# %%
#  Fitting on the training data
NB = classifiers['Naive Bayes']()
NB.fit(df.drop('y',axis=1), df['y'])

# Getting predictions and getting the accuracy score with confusion matrix and classification report
test_pred = NB.predict(df_test.drop('y',axis=1))
test_score_NB = accuracy_score(test_pred, df_test['y'])
print('The test accuracy is %0.2f'%test_score_NB)
print(classification_report(test_pred, df_test['y']))
_,test_conf_NB = plot_confusion(test_pred, df_test['y'],'Naive Bayes Test Scores ()')
# Out:
# The test accuracy is 0.31
#               precision    recall  f1-score   support
#
#            1       0.78      0.39      0.52        18
#            2       0.11      0.14      0.12         7
#            3       0.00      0.00      0.00         1
#
#     accuracy                           0.31        26
#    macro avg       0.30      0.18      0.21        26
# weighted avg       0.57      0.31      0.39        26

# %% [markdown]
# # 2. Logistic Regression

# %%
val_conf_LR, val_scores_LR, val_time_LR = classify(cancer_prepared, np.array(df['y']),
                                              classifiers['Logistic Regression'](solver='liblinear',
                                                                                 multi_class = 'ovr'))
print('The average training time is %0.6f seconds'%val_time_LR.mean())
# Out:
# The model score is 0.779 (+/- 0.147)
# The IQR is 0.233 between [0.67,0.90]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.79      0.91      0.85       330
#          2.0       0.69      0.76      0.72       330
#          3.0       0.88      0.68      0.77       340
#
#     accuracy                           0.78      1000
#    macro avg       0.79      0.78      0.78      1000
# weighted avg       0.79      0.78      0.78      1000
#
# The average training time is 0.010771 seconds

# %%
scaled_test = scaler.transform(df_test.drop('y',axis=1))

# %%
#  Fitting on the training data
LR = classifiers['Logistic Regression'](solver='liblinear',  multi_class = 'ovr')
LR.fit(cancer_prepared, np.array(df['y']))

# Getting predictions and getting the accuracy score with confusion matrix and classification report
test_pred = LR.predict(scaled_test)
test_score_LR = accuracy_score(test_pred, df_test['y'])
print('The test accuracy is %0.2f'%test_score_LR)
print(classification_report(test_pred, df_test['y']))
_,test_conf_LR = plot_confusion(test_pred, df_test['y'],LR)
# Out:
# The test accuracy is 0.73
#               precision    recall  f1-score   support
#
#            1       0.78      0.78      0.78         9
#            2       0.67      0.75      0.71         8
#            3       0.75      0.67      0.71         9
#
#     accuracy                           0.73        26
#    macro avg       0.73      0.73      0.73        26
# weighted avg       0.73      0.73      0.73        26

# %% [markdown]
# # 3. Ensemble - Random Forests

# %% [markdown]
# n_estimators=500

# %%
val_conf_RF, val_scores_RF, val_time_RF = classify(df.drop('y',axis=1), df['y'],
                                                   classifiers['RF'](n_estimators = 500, n_jobs=-1))
print('The average training time is %0.6f seconds'%val_time_RF.mean())
# Out:
# The model score is 0.688 (+/- 0.115)
# The IQR is 0.167 between [0.58,0.75]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.75      0.75      0.75       330
#          2.0       0.55      0.64      0.59       330
#          3.0       0.76      0.63      0.69       340
#
#     accuracy                           0.67      1000
#    macro avg       0.69      0.67      0.68      1000
# weighted avg       0.69      0.67      0.68      1000
#
# The average training time is 0.569634 seconds

# %%
#  Fitting on the training data
RF = classifiers['RF'](n_estimators = 500, n_jobs=-1)
RF.fit(df.drop('y',axis=1), df['y'])

# Getting predictions and getting the accuracy score with confusion matrix and classification report
test_pred = RF.predict(df_test.drop('y',axis=1))
test_score_RF = accuracy_score(test_pred, df_test['y'])
print('The test accuracy is %0.2f'%test_score_RF)
print(classification_report(test_pred, df_test['y']))
_,test_conf_RF = plot_confusion(test_pred, df_test['y'],RF)
# Out:
# The test accuracy is 0.58
#               precision    recall  f1-score   support
#
#            1       0.67      0.67      0.67         9
#            2       0.56      0.50      0.53        10
#            3       0.50      0.57      0.53         7
#
#     accuracy                           0.58        26
#    macro avg       0.57      0.58      0.58        26
# weighted avg       0.58      0.58      0.58        26

# %% [markdown]
# # 4. Ensemble - AdaBoost

# %%
val_conf_Ada, val_scores_Ada, val_time_Ada = classify(df.drop('y',axis=1), np.array(df['y']),
                                                      classifiers['AdaBoost'](n_estimators=200))
print('The average training time is %0.6f seconds'%val_time_Ada.mean())
# Out:
# The model score is 0.566 (+/- 0.147)
# The IQR is 0.222 between [0.44,0.67]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.61      0.54      0.58       330
#          2.0       0.46      0.65      0.54       330
#          3.0       0.72      0.52      0.60       340
#
#     accuracy                           0.57      1000
#    macro avg       0.60      0.57      0.57      1000
# weighted avg       0.60      0.57      0.57      1000
#
# The average training time is 0.722752 seconds

# %%
#  Fitting on the training data
Ada = classifiers['AdaBoost'](n_estimators = 200)
Ada.fit(df.drop('y',axis=1), np.array(df['y']))

# Getting predictions and getting the accuracy score with confusion matrix and classification report
test_pred = Ada.predict(df_test.drop('y',axis=1))
test_score_Ada = accuracy_score(test_pred, np.array(df_test['y']))
print('The test accuracy is %0.2f'%test_score_Ada)
print(classification_report(test_pred, np.array(df_test['y'])))
_,test_conf_Ada = plot_confusion(test_pred, df_test['y'],RF)
# Out:
# The test accuracy is 0.50
#               precision    recall  f1-score   support
#
#            1       0.56      0.71      0.63         7
#            2       0.67      0.43      0.52        14
#            3       0.25      0.40      0.31         5
#
#     accuracy                           0.50        26
#    macro avg       0.49      0.51      0.48        26
# weighted avg       0.56      0.50      0.51        26

# %% [markdown]
# # 5. K-Nearest Neighbours

# %%
np.shape(df['y'])
# Out:
# (100,)

# %%
KNN_scores = []
for k in range(1,21):
    _, val_scores_KNN, _= classify(cancer_prepared, np.array(df['y']),classifiers['KNN'](k))
    KNN_scores.append(np.round(val_scores_KNN.mean(),4))
# Out:
# The model score is 0.592 (+/- 0.137)
# The IQR is 0.222 between [0.44,0.67]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.63      0.82      0.71       330
#          2.0       0.45      0.45      0.45       330
#          3.0       0.71      0.50      0.59       340
#
#     accuracy                           0.59      1000
#    macro avg       0.60      0.59      0.58      1000
# weighted avg       0.60      0.59      0.58      1000
#
# The model score is 0.577 (+/- 0.157)
# The IQR is 0.222 between [0.44,0.67]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.51      0.88      0.64       330
#          2.0       0.50      0.42      0.46       330
#          3.0       0.93      0.41      0.57       340
#
#     accuracy                           0.57      1000
#    macro avg       0.65      0.57      0.56      1000
# weighted avg       0.65      0.57      0.56      1000
#
# The model score is 0.616 (+/- 0.129)
# The IQR is 0.167 between [0.50,0.67]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.56      0.85      0.67       330
#          2.0       0.55      0.48      0.52       330
#          3.0       0.86      0.53      0.65       340
#
#     accuracy                           0.62      1000
#    macro avg       0.66      0.62      0.62      1000
# weighted avg       0.66      0.62      0.62      1000
#
# The model score is 0.648 (+/- 0.173)
# The IQR is 0.278 between [0.50,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.59      0.88      0.71       330
#          2.0       0.58      0.58      0.58       330
#          3.0       0.94      0.50      0.65       340
#
#     accuracy                           0.65      1000
#    macro avg       0.70      0.65      0.65      1000
# weighted avg       0.71      0.65      0.65      1000
#
# The model score is 0.668 (+/- 0.212)
# The IQR is 0.389 between [0.50,0.89]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.61      0.85      0.71       330
#          2.0       0.61      0.67      0.64       330
#          3.0       0.94      0.50      0.65       340
#
#     accuracy                           0.67      1000
#    macro avg       0.72      0.67      0.67      1000
# weighted avg       0.72      0.67      0.67      1000
#
# The model score is 0.659 (+/- 0.155)
# The IQR is 0.278 between [0.50,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.55      0.85      0.67       330
#          2.0       0.65      0.61      0.62       330
#          3.0       1.00      0.53      0.69       340
#
#     accuracy                           0.66      1000
#    macro avg       0.73      0.66      0.66      1000
# weighted avg       0.73      0.66      0.66      1000
#
# The model score is 0.649 (+/- 0.149)
# The IQR is 0.222 between [0.56,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.57      0.82      0.68       330
#          2.0       0.58      0.64      0.61       330
#          3.0       1.00      0.50      0.67       340
#
#     accuracy                           0.65      1000
#    macro avg       0.72      0.65      0.65      1000
# weighted avg       0.72      0.65      0.65      1000
#
# The model score is 0.630 (+/- 0.156)
# The IQR is 0.278 between [0.50,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.55      0.82      0.66       330
#          2.0       0.58      0.58      0.58       330
#          3.0       0.94      0.50      0.65       340
#
#     accuracy                           0.63      1000
#    macro avg       0.69      0.63      0.63      1000
# weighted avg       0.69      0.63      0.63      1000
#
# The model score is 0.627 (+/- 0.153)
# The IQR is 0.278 between [0.50,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.55      0.85      0.67       330
#          2.0       0.58      0.55      0.56       330
#          3.0       0.94      0.50      0.65       340
#
#     accuracy                           0.63      1000
#    macro avg       0.69      0.63      0.63      1000
# weighted avg       0.69      0.63      0.63      1000
#
# The model score is 0.619 (+/- 0.162)
# The IQR is 0.333 between [0.44,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.57      0.85      0.68       330
#          2.0       0.54      0.58      0.56       330
#          3.0       0.94      0.44      0.60       340
#
#     accuracy                           0.62      1000
#    macro avg       0.68      0.62      0.61      1000
# weighted avg       0.69      0.62      0.61      1000
#
# The model score is 0.627 (+/- 0.153)
# The IQR is 0.278 between [0.50,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.57      0.85      0.68       330
#          2.0       0.55      0.55      0.55       330
#          3.0       0.94      0.50      0.65       340
#
#     accuracy                           0.63      1000
#    macro avg       0.69      0.63      0.63      1000
# weighted avg       0.69      0.63      0.63      1000
#
# The model score is 0.636 (+/- 0.146)
# The IQR is 0.222 between [0.56,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.57      0.85      0.68       330
#          2.0       0.58      0.55      0.56       330
#          3.0       0.90      0.53      0.67       340
#
#     accuracy                           0.64      1000
#    macro avg       0.68      0.64      0.64      1000
# weighted avg       0.69      0.64      0.64      1000
#
# The model score is 0.636 (+/- 0.183)
# The IQR is 0.278 between [0.50,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.56      0.85      0.67       330
#          2.0       0.59      0.61      0.60       330
#          3.0       1.00      0.47      0.64       340
#
#     accuracy                           0.64      1000
#    macro avg       0.72      0.64      0.64      1000
# weighted avg       0.72      0.64      0.64      1000
#
# The model score is 0.641 (+/- 0.171)
# The IQR is 0.278 between [0.50,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.55      0.82      0.66       330
#          2.0       0.58      0.58      0.58       330
#          3.0       1.00      0.53      0.69       340
#
#     accuracy                           0.64      1000
#    macro avg       0.71      0.64      0.64      1000
# weighted avg       0.71      0.64      0.64      1000
#
# The model score is 0.605 (+/- 0.198)
# The IQR is 0.361 between [0.42,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.55      0.85      0.67       330
#          2.0       0.55      0.52      0.53       330
#          3.0       0.89      0.47      0.62       340
#
#     accuracy                           0.61      1000
#    macro avg       0.66      0.61      0.60      1000
# weighted avg       0.66      0.61      0.60      1000
#
# The model score is 0.594 (+/- 0.190)
# The IQR is 0.278 between [0.50,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.53      0.85      0.65       330
#          2.0       0.55      0.48      0.52       330
#          3.0       0.89      0.47      0.62       340
#
#     accuracy                           0.60      1000
#    macro avg       0.66      0.60      0.59      1000
# weighted avg       0.66      0.60      0.59      1000
#
# The model score is 0.626 (+/- 0.214)
# The IQR is 0.278 between [0.50,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.54      0.85      0.66       330
#          2.0       0.60      0.55      0.57       330
#          3.0       0.94      0.50      0.65       340
#
#     accuracy                           0.63      1000
#    macro avg       0.69      0.63      0.63      1000
# weighted avg       0.70      0.63      0.63      1000
#
# The model score is 0.594 (+/- 0.190)
# The IQR is 0.278 between [0.50,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.50      0.85      0.63       330
#          2.0       0.62      0.55      0.58       330
#          3.0       0.93      0.41      0.57       340
#
#     accuracy                           0.60      1000
#    macro avg       0.68      0.60      0.59      1000
# weighted avg       0.69      0.60      0.59      1000
# The model score is 0.594 (+/- 0.176)
# The IQR is 0.333 between [0.44,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.51      0.85      0.64       330
#          2.0       0.59      0.58      0.58       330
#          3.0       1.00      0.38      0.55       340
#
#     accuracy                           0.60      1000
#    macro avg       0.70      0.60      0.59      1000
# weighted avg       0.70      0.60      0.59      1000
#
# The model score is 0.611 (+/- 0.175)
# The IQR is 0.333 between [0.44,0.78]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.51      0.85      0.64       330
#          2.0       0.65      0.61      0.62       330
#          3.0       1.00      0.41      0.58       340
#
#     accuracy                           0.62      1000
#    macro avg       0.72      0.62      0.61      1000
# weighted avg       0.72      0.62      0.61      1000

# %%
plt.figure(figsize=(20,20))
plt.plot([k for k in range(1, 21)], KNN_scores, color = 'red')
for i in range(1,21):
    plt.text(i, KNN_scores[i-1], (i, KNN_scores[i-1]))
plt.xticks([i for i in range(1, 21)])
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Scores')
plt.title('K Neighbors Classifier scores for different K values')
# Out:
# Text(0.5, 1.0, 'K Neighbors Classifier scores for different K values')

# %%
val_conf_KNN, val_scores_KNN, val_time_KNN = classify(cancer_prepared, np.array(df['y']),
                                                      classifiers['KNN'](KNN_scores.index(max(KNN_scores))+1))
print('The average training time is %0.6f seconds'%val_time_KNN.mean())
# Out:
# The model score is 0.668 (+/- 0.212)
# The IQR is 0.389 between [0.50,0.89]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.61      0.85      0.71       330
#          2.0       0.61      0.67      0.64       330
#          3.0       0.94      0.50      0.65       340
#
#     accuracy                           0.67      1000
#    macro avg       0.72      0.67      0.67      1000
# weighted avg       0.72      0.67      0.67      1000
#
# The average training time is 0.002183 seconds

# %%
#  Fitting on the training data
KNN = classifiers['KNN'](KNN_scores.index(max(KNN_scores))+1)
KNN.fit(cancer_prepared, np.array(df['y']))

# Getting predictions and getting the accuracy score with confusion matrix and classification report
test_pred = KNN.predict(scaled_test)
test_score_KNN = accuracy_score(test_pred, np.array(df_test['y']))
print('The test accuracy is %0.4f'%test_score_KNN)
print(classification_report(test_pred, np.array(df_test['y'])))
_,test_conf_KNN = plot_confusion(test_pred, df_test['y'],KNN)
# Out:
# The test accuracy is 0.3846
#               precision    recall  f1-score   support
#
#            1       0.67      0.43      0.52        14
#            2       0.33      0.27      0.30        11
#            3       0.12      1.00      0.22         1
#
#     accuracy                           0.38        26
#    macro avg       0.38      0.57      0.35        26
# weighted avg       0.50      0.38      0.42        26

# %% [markdown]
# # 6. Support Vector Machines - Linear Kernel

# %%
from time import time

# %%
param_grid = [
    {'C':2.**np.linspace(-5,15,21)}
]

clf = SVC(kernel='linear')
start = time()
grid_search_L = GridSearchCV(clf, param_grid, cv=10, n_jobs=-1)
grid_search_L.fit(cancer_prepared, np.array(df['y']))
print('Time take to search for the best combination si %0.6f seconds'% (time()-start))
# Out:
# Time take to search for the best combination si 6.860279 seconds
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
val_conf_SVM_L_opt, val_scores_SVM_L_opt, val_time_SVM_L = classify(cancer_prepared, np.array(df['y']),
                                                 classifiers['SVM'](kernel='linear', C=grid_search_L.best_params_['C']))

print('The average training time is %0.6f seconds'%val_time_SVM_L.mean())
# Out:
# The model score is 0.729 (+/- 0.186)
# The IQR is 0.333 between [0.56,0.89]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.78      0.85      0.81       330
#          2.0       0.60      0.79      0.68       330
#          3.0       0.90      0.56      0.69       340
#
#     accuracy                           0.73      1000
#    macro avg       0.76      0.73      0.73      1000
# weighted avg       0.76      0.73      0.73      1000
#
# The average training time is 0.004989 seconds

# %%
cvres = grid_search_L.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# 0.66 {'C': 0.03125, 'gamma': 3.0517578125e-05}
# 0.66 {'C': 0.03125, 'gamma': 6.103515625e-05}
# 0.66 {'C': 0.03125, 'gamma': 0.0001220703125}
# 0.66 {'C': 0.03125, 'gamma': 0.000244140625}
# 0.66 {'C': 0.03125, 'gamma': 0.00048828125}
# 0.66 {'C': 0.03125, 'gamma': 0.0009765625}
# 0.66 {'C': 0.03125, 'gamma': 0.001953125}
# 0.66 {'C': 0.03125, 'gamma': 0.00390625}
# 0.66 {'C': 0.03125, 'gamma': 0.0078125}
# 0.66 {'C': 0.03125, 'gamma': 0.015625}
# 0.66 {'C': 0.03125, 'gamma': 0.03125}
# 0.66 {'C': 0.03125, 'gamma': 0.0625}
# 0.66 {'C': 0.03125, 'gamma': 0.125}
# 0.66 {'C': 0.03125, 'gamma': 0.25}
# 0.66 {'C': 0.03125, 'gamma': 0.5}
# 0.66 {'C': 0.03125, 'gamma': 1.0}
# 0.66 {'C': 0.03125, 'gamma': 2.0}
# 0.66 {'C': 0.03125, 'gamma': 4.0}
# 0.66 {'C': 0.03125, 'gamma': 8.0}
# 0.72 {'C': 0.0625, 'gamma': 3.0517578125e-05}
# 0.72 {'C': 0.0625, 'gamma': 6.103515625e-05}
# 0.72 {'C': 0.0625, 'gamma': 0.0001220703125}
# 0.72 {'C': 0.0625, 'gamma': 0.000244140625}
# 0.72 {'C': 0.0625, 'gamma': 0.00048828125}
# 0.72 {'C': 0.0625, 'gamma': 0.0009765625}
# 0.72 {'C': 0.0625, 'gamma': 0.001953125}
# 0.72 {'C': 0.0625, 'gamma': 0.00390625}
# 0.72 {'C': 0.0625, 'gamma': 0.0078125}
# 0.72 {'C': 0.0625, 'gamma': 0.015625}
# 0.72 {'C': 0.0625, 'gamma': 0.03125}
# 0.72 {'C': 0.0625, 'gamma': 0.0625}
# 0.72 {'C': 0.0625, 'gamma': 0.125}
# 0.72 {'C': 0.0625, 'gamma': 0.25}
# 0.72 {'C': 0.0625, 'gamma': 0.5}
# 0.72 {'C': 0.0625, 'gamma': 1.0}
# 0.72 {'C': 0.0625, 'gamma': 2.0}
# 0.72 {'C': 0.0625, 'gamma': 4.0}
# 0.72 {'C': 0.0625, 'gamma': 8.0}
# 0.73 {'C': 0.125, 'gamma': 3.0517578125e-05}
# 0.73 {'C': 0.125, 'gamma': 6.103515625e-05}
# 0.73 {'C': 0.125, 'gamma': 0.0001220703125}
# 0.73 {'C': 0.125, 'gamma': 0.000244140625}
# 0.73 {'C': 0.125, 'gamma': 0.00048828125}
# 0.73 {'C': 0.125, 'gamma': 0.0009765625}
# 0.73 {'C': 0.125, 'gamma': 0.001953125}
# 0.73 {'C': 0.125, 'gamma': 0.00390625}
# 0.73 {'C': 0.125, 'gamma': 0.0078125}
# 0.73 {'C': 0.125, 'gamma': 0.015625}
# 0.73 {'C': 0.125, 'gamma': 0.03125}
# 0.73 {'C': 0.125, 'gamma': 0.0625}
# 0.73 {'C': 0.125, 'gamma': 0.125}
# 0.73 {'C': 0.125, 'gamma': 0.25}
# 0.73 {'C': 0.125, 'gamma': 0.5}
# 0.73 {'C': 0.125, 'gamma': 1.0}
# 0.73 {'C': 0.125, 'gamma': 2.0}
# 0.73 {'C': 0.125, 'gamma': 4.0}
# 0.73 {'C': 0.125, 'gamma': 8.0}
# 0.71 {'C': 0.25, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 0.25, 'gamma': 6.103515625e-05}
# 0.71 {'C': 0.25, 'gamma': 0.0001220703125}
# 0.71 {'C': 0.25, 'gamma': 0.000244140625}
# 0.71 {'C': 0.25, 'gamma': 0.00048828125}
# 0.71 {'C': 0.25, 'gamma': 0.0009765625}
# 0.71 {'C': 0.25, 'gamma': 0.001953125}
# 0.71 {'C': 0.25, 'gamma': 0.00390625}
# 0.71 {'C': 0.25, 'gamma': 0.0078125}
# 0.71 {'C': 0.25, 'gamma': 0.015625}
# 0.71 {'C': 0.25, 'gamma': 0.03125}
# 0.71 {'C': 0.25, 'gamma': 0.0625}
# 0.71 {'C': 0.25, 'gamma': 0.125}
# 0.71 {'C': 0.25, 'gamma': 0.25}
# 0.71 {'C': 0.25, 'gamma': 0.5}
# 0.71 {'C': 0.25, 'gamma': 1.0}
# 0.71 {'C': 0.25, 'gamma': 2.0}
# 0.71 {'C': 0.25, 'gamma': 4.0}
# 0.71 {'C': 0.25, 'gamma': 8.0}
# 0.73 {'C': 0.5, 'gamma': 3.0517578125e-05}
# 0.73 {'C': 0.5, 'gamma': 6.103515625e-05}
# 0.73 {'C': 0.5, 'gamma': 0.0001220703125}
# 0.73 {'C': 0.5, 'gamma': 0.000244140625}
# 0.73 {'C': 0.5, 'gamma': 0.00048828125}
# 0.73 {'C': 0.5, 'gamma': 0.0009765625}
# 0.73 {'C': 0.5, 'gamma': 0.001953125}
# 0.73 {'C': 0.5, 'gamma': 0.00390625}
# 0.73 {'C': 0.5, 'gamma': 0.0078125}
# 0.73 {'C': 0.5, 'gamma': 0.015625}
# 0.73 {'C': 0.5, 'gamma': 0.03125}
# 0.73 {'C': 0.5, 'gamma': 0.0625}
# 0.73 {'C': 0.5, 'gamma': 0.125}
# 0.73 {'C': 0.5, 'gamma': 0.25}
# 0.73 {'C': 0.5, 'gamma': 0.5}
# 0.73 {'C': 0.5, 'gamma': 1.0}
# 0.73 {'C': 0.5, 'gamma': 2.0}
# 0.73 {'C': 0.5, 'gamma': 4.0}
# 0.73 {'C': 0.5, 'gamma': 8.0}
# 0.72 {'C': 1.0, 'gamma': 3.0517578125e-05}
# 0.72 {'C': 1.0, 'gamma': 6.103515625e-05}
# 0.72 {'C': 1.0, 'gamma': 0.0001220703125}
# 0.72 {'C': 1.0, 'gamma': 0.000244140625}
# 0.72 {'C': 1.0, 'gamma': 0.00048828125}
# 0.72 {'C': 1.0, 'gamma': 0.0009765625}
# 0.72 {'C': 1.0, 'gamma': 0.001953125}
# 0.72 {'C': 1.0, 'gamma': 0.00390625}
# 0.72 {'C': 1.0, 'gamma': 0.0078125}
# 0.72 {'C': 1.0, 'gamma': 0.015625}
# 0.72 {'C': 1.0, 'gamma': 0.03125}
# 0.72 {'C': 1.0, 'gamma': 0.0625}
# 0.72 {'C': 1.0, 'gamma': 0.125}
# 0.72 {'C': 1.0, 'gamma': 0.25}
# 0.72 {'C': 1.0, 'gamma': 0.5}
# 0.72 {'C': 1.0, 'gamma': 1.0}
# 0.72 {'C': 1.0, 'gamma': 2.0}
# 0.72 {'C': 1.0, 'gamma': 4.0}
# 0.72 {'C': 1.0, 'gamma': 8.0}
# 0.71 {'C': 2.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 2.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 2.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 2.0, 'gamma': 0.000244140625}
# 0.71 {'C': 2.0, 'gamma': 0.00048828125}
# 0.71 {'C': 2.0, 'gamma': 0.0009765625}
# 0.71 {'C': 2.0, 'gamma': 0.001953125}
# 0.71 {'C': 2.0, 'gamma': 0.00390625}
# 0.71 {'C': 2.0, 'gamma': 0.0078125}
# 0.71 {'C': 2.0, 'gamma': 0.015625}
# 0.71 {'C': 2.0, 'gamma': 0.03125}
# 0.71 {'C': 2.0, 'gamma': 0.0625}
# 0.71 {'C': 2.0, 'gamma': 0.125}
# 0.71 {'C': 2.0, 'gamma': 0.25}
# 0.71 {'C': 2.0, 'gamma': 0.5}
# 0.71 {'C': 2.0, 'gamma': 1.0}
# 0.71 {'C': 2.0, 'gamma': 2.0}
# 0.71 {'C': 2.0, 'gamma': 4.0}
# 0.71 {'C': 2.0, 'gamma': 8.0}
# 0.71 {'C': 4.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 4.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 4.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 4.0, 'gamma': 0.000244140625}
# 0.71 {'C': 4.0, 'gamma': 0.00048828125}
# 0.71 {'C': 4.0, 'gamma': 0.0009765625}
# 0.71 {'C': 4.0, 'gamma': 0.001953125}
# 0.71 {'C': 4.0, 'gamma': 0.00390625}
# 0.71 {'C': 4.0, 'gamma': 0.0078125}
# 0.71 {'C': 4.0, 'gamma': 0.015625}
# 0.71 {'C': 4.0, 'gamma': 0.03125}
# 0.71 {'C': 4.0, 'gamma': 0.0625}
# 0.71 {'C': 4.0, 'gamma': 0.125}
# 0.71 {'C': 4.0, 'gamma': 0.25}
# 0.71 {'C': 4.0, 'gamma': 0.5}
# 0.71 {'C': 4.0, 'gamma': 1.0}
# 0.71 {'C': 4.0, 'gamma': 2.0}
# 0.71 {'C': 4.0, 'gamma': 4.0}
# 0.71 {'C': 4.0, 'gamma': 8.0}
# 0.71 {'C': 8.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 8.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 8.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 8.0, 'gamma': 0.000244140625}
# 0.71 {'C': 8.0, 'gamma': 0.00048828125}
# 0.71 {'C': 8.0, 'gamma': 0.0009765625}
# 0.71 {'C': 8.0, 'gamma': 0.001953125}
# 0.71 {'C': 8.0, 'gamma': 0.00390625}
# 0.71 {'C': 8.0, 'gamma': 0.0078125}
# 0.71 {'C': 8.0, 'gamma': 0.015625}
# 0.71 {'C': 8.0, 'gamma': 0.03125}
# 0.71 {'C': 8.0, 'gamma': 0.0625}
# 0.71 {'C': 8.0, 'gamma': 0.125}
# 0.71 {'C': 8.0, 'gamma': 0.25}
# 0.71 {'C': 8.0, 'gamma': 0.5}
# 0.71 {'C': 8.0, 'gamma': 1.0}
# 0.71 {'C': 8.0, 'gamma': 2.0}
# 0.71 {'C': 8.0, 'gamma': 4.0}
# 0.71 {'C': 8.0, 'gamma': 8.0}
# 0.71 {'C': 16.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 16.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 16.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 16.0, 'gamma': 0.000244140625}
# 0.71 {'C': 16.0, 'gamma': 0.00048828125}
# 0.71 {'C': 16.0, 'gamma': 0.0009765625}
# 0.71 {'C': 16.0, 'gamma': 0.001953125}
# 0.71 {'C': 16.0, 'gamma': 0.00390625}
# 0.71 {'C': 16.0, 'gamma': 0.0078125}
# 0.71 {'C': 16.0, 'gamma': 0.015625}
# 0.71 {'C': 16.0, 'gamma': 0.03125}
# 0.71 {'C': 16.0, 'gamma': 0.0625}
# 0.71 {'C': 16.0, 'gamma': 0.125}
# 0.71 {'C': 16.0, 'gamma': 0.25}
# 0.71 {'C': 16.0, 'gamma': 0.5}
# 0.71 {'C': 16.0, 'gamma': 1.0}
# 0.71 {'C': 16.0, 'gamma': 2.0}
# 0.71 {'C': 16.0, 'gamma': 4.0}
# 0.71 {'C': 16.0, 'gamma': 8.0}
# 0.71 {'C': 32.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 32.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 32.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 32.0, 'gamma': 0.000244140625}
# 0.71 {'C': 32.0, 'gamma': 0.00048828125}
# 0.71 {'C': 32.0, 'gamma': 0.0009765625}
# 0.71 {'C': 32.0, 'gamma': 0.001953125}
# 0.71 {'C': 32.0, 'gamma': 0.00390625}
# 0.71 {'C': 32.0, 'gamma': 0.0078125}
# 0.71 {'C': 32.0, 'gamma': 0.015625}
# 0.71 {'C': 32.0, 'gamma': 0.03125}
# 0.71 {'C': 32.0, 'gamma': 0.0625}
# 0.71 {'C': 32.0, 'gamma': 0.125}
# 0.71 {'C': 32.0, 'gamma': 0.25}
# 0.71 {'C': 32.0, 'gamma': 0.5}
# 0.71 {'C': 32.0, 'gamma': 1.0}
# 0.71 {'C': 32.0, 'gamma': 2.0}
# 0.71 {'C': 32.0, 'gamma': 4.0}
# 0.71 {'C': 32.0, 'gamma': 8.0}
# 0.71 {'C': 64.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 64.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 64.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 64.0, 'gamma': 0.000244140625}
# 0.71 {'C': 64.0, 'gamma': 0.00048828125}
# 0.71 {'C': 64.0, 'gamma': 0.0009765625}
# 0.71 {'C': 64.0, 'gamma': 0.001953125}
# 0.71 {'C': 64.0, 'gamma': 0.00390625}
# 0.71 {'C': 64.0, 'gamma': 0.0078125}
# 0.71 {'C': 64.0, 'gamma': 0.015625}
# 0.71 {'C': 64.0, 'gamma': 0.03125}
# 0.71 {'C': 64.0, 'gamma': 0.0625}
# 0.71 {'C': 64.0, 'gamma': 0.125}
# 0.71 {'C': 64.0, 'gamma': 0.25}
# 0.71 {'C': 64.0, 'gamma': 0.5}
# 0.71 {'C': 64.0, 'gamma': 1.0}
# 0.71 {'C': 64.0, 'gamma': 2.0}
# 0.71 {'C': 64.0, 'gamma': 4.0}
# 0.71 {'C': 64.0, 'gamma': 8.0}
# 0.71 {'C': 128.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 128.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 128.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 128.0, 'gamma': 0.000244140625}
# 0.71 {'C': 128.0, 'gamma': 0.00048828125}
# 0.71 {'C': 128.0, 'gamma': 0.0009765625}
# 0.71 {'C': 128.0, 'gamma': 0.001953125}
# 0.71 {'C': 128.0, 'gamma': 0.00390625}
# 0.71 {'C': 128.0, 'gamma': 0.0078125}
# 0.71 {'C': 128.0, 'gamma': 0.015625}
# 0.71 {'C': 128.0, 'gamma': 0.03125}
# 0.71 {'C': 128.0, 'gamma': 0.0625}
# 0.71 {'C': 128.0, 'gamma': 0.125}
# 0.71 {'C': 128.0, 'gamma': 0.25}
# 0.71 {'C': 128.0, 'gamma': 0.5}
# 0.71 {'C': 128.0, 'gamma': 1.0}
# 0.71 {'C': 128.0, 'gamma': 2.0}
# 0.71 {'C': 128.0, 'gamma': 4.0}
# 0.71 {'C': 128.0, 'gamma': 8.0}
# 0.71 {'C': 256.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 256.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 256.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 256.0, 'gamma': 0.000244140625}
# 0.71 {'C': 256.0, 'gamma': 0.00048828125}
# 0.71 {'C': 256.0, 'gamma': 0.0009765625}
# 0.71 {'C': 256.0, 'gamma': 0.001953125}
# 0.71 {'C': 256.0, 'gamma': 0.00390625}
# 0.71 {'C': 256.0, 'gamma': 0.0078125}
# 0.71 {'C': 256.0, 'gamma': 0.015625}
# 0.71 {'C': 256.0, 'gamma': 0.03125}
# 0.71 {'C': 256.0, 'gamma': 0.0625}
# 0.71 {'C': 256.0, 'gamma': 0.125}
# 0.71 {'C': 256.0, 'gamma': 0.25}
# 0.71 {'C': 256.0, 'gamma': 0.5}
# 0.71 {'C': 256.0, 'gamma': 1.0}
# 0.71 {'C': 256.0, 'gamma': 2.0}
# 0.71 {'C': 256.0, 'gamma': 4.0}
# 0.71 {'C': 256.0, 'gamma': 8.0}
# 0.71 {'C': 512.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 512.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 512.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 512.0, 'gamma': 0.000244140625}
# 0.71 {'C': 512.0, 'gamma': 0.00048828125}
# 0.71 {'C': 512.0, 'gamma': 0.0009765625}
# 0.71 {'C': 512.0, 'gamma': 0.001953125}
# 0.71 {'C': 512.0, 'gamma': 0.00390625}
# 0.71 {'C': 512.0, 'gamma': 0.0078125}
# 0.71 {'C': 512.0, 'gamma': 0.015625}
# 0.71 {'C': 512.0, 'gamma': 0.03125}
# 0.71 {'C': 512.0, 'gamma': 0.0625}
# 0.71 {'C': 512.0, 'gamma': 0.125}
# 0.71 {'C': 512.0, 'gamma': 0.25}
# 0.71 {'C': 512.0, 'gamma': 0.5}
# 0.71 {'C': 512.0, 'gamma': 1.0}
# 0.71 {'C': 512.0, 'gamma': 2.0}
# 0.71 {'C': 512.0, 'gamma': 4.0}
# 0.71 {'C': 512.0, 'gamma': 8.0}
# 0.71 {'C': 1024.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 1024.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 1024.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 1024.0, 'gamma': 0.000244140625}
# 0.71 {'C': 1024.0, 'gamma': 0.00048828125}
# 0.71 {'C': 1024.0, 'gamma': 0.0009765625}
# 0.71 {'C': 1024.0, 'gamma': 0.001953125}
# 0.71 {'C': 1024.0, 'gamma': 0.00390625}
# 0.71 {'C': 1024.0, 'gamma': 0.0078125}
# 0.71 {'C': 1024.0, 'gamma': 0.015625}
# 0.71 {'C': 1024.0, 'gamma': 0.03125}
# 0.71 {'C': 1024.0, 'gamma': 0.0625}
# 0.71 {'C': 1024.0, 'gamma': 0.125}
# 0.71 {'C': 1024.0, 'gamma': 0.25}
# 0.71 {'C': 1024.0, 'gamma': 0.5}
# 0.71 {'C': 1024.0, 'gamma': 1.0}
# 0.71 {'C': 1024.0, 'gamma': 2.0}
# 0.71 {'C': 1024.0, 'gamma': 4.0}
# 0.71 {'C': 1024.0, 'gamma': 8.0}
# 0.71 {'C': 2048.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 2048.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 2048.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 2048.0, 'gamma': 0.000244140625}
# 0.71 {'C': 2048.0, 'gamma': 0.00048828125}
# 0.71 {'C': 2048.0, 'gamma': 0.0009765625}
# 0.71 {'C': 2048.0, 'gamma': 0.001953125}
# 0.71 {'C': 2048.0, 'gamma': 0.00390625}
# 0.71 {'C': 2048.0, 'gamma': 0.0078125}
# 0.71 {'C': 2048.0, 'gamma': 0.015625}
# 0.71 {'C': 2048.0, 'gamma': 0.03125}
# 0.71 {'C': 2048.0, 'gamma': 0.0625}
# 0.71 {'C': 2048.0, 'gamma': 0.125}
# 0.71 {'C': 2048.0, 'gamma': 0.25}
# 0.71 {'C': 2048.0, 'gamma': 0.5}
# 0.71 {'C': 2048.0, 'gamma': 1.0}
# 0.71 {'C': 2048.0, 'gamma': 2.0}
# 0.71 {'C': 2048.0, 'gamma': 4.0}
# 0.71 {'C': 2048.0, 'gamma': 8.0}
# 0.71 {'C': 4096.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 4096.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 4096.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 4096.0, 'gamma': 0.000244140625}
# 0.71 {'C': 4096.0, 'gamma': 0.00048828125}
# 0.71 {'C': 4096.0, 'gamma': 0.0009765625}
# 0.71 {'C': 4096.0, 'gamma': 0.001953125}
# 0.71 {'C': 4096.0, 'gamma': 0.00390625}
# 0.71 {'C': 4096.0, 'gamma': 0.0078125}
# 0.71 {'C': 4096.0, 'gamma': 0.015625}
# 0.71 {'C': 4096.0, 'gamma': 0.03125}
# 0.71 {'C': 4096.0, 'gamma': 0.0625}
# 0.71 {'C': 4096.0, 'gamma': 0.125}
# 0.71 {'C': 4096.0, 'gamma': 0.25}
# 0.71 {'C': 4096.0, 'gamma': 0.5}
# 0.71 {'C': 4096.0, 'gamma': 1.0}
# 0.71 {'C': 4096.0, 'gamma': 2.0}
# 0.71 {'C': 4096.0, 'gamma': 4.0}
# 0.71 {'C': 4096.0, 'gamma': 8.0}
# 0.71 {'C': 8192.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 8192.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 8192.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 8192.0, 'gamma': 0.000244140625}
# 0.71 {'C': 8192.0, 'gamma': 0.00048828125}
# 0.71 {'C': 8192.0, 'gamma': 0.0009765625}
# 0.71 {'C': 8192.0, 'gamma': 0.001953125}
# 0.71 {'C': 8192.0, 'gamma': 0.00390625}
# 0.71 {'C': 8192.0, 'gamma': 0.0078125}
# 0.71 {'C': 8192.0, 'gamma': 0.015625}
# 0.71 {'C': 8192.0, 'gamma': 0.03125}
# 0.71 {'C': 8192.0, 'gamma': 0.0625}
# 0.71 {'C': 8192.0, 'gamma': 0.125}
# 0.71 {'C': 8192.0, 'gamma': 0.25}
# 0.71 {'C': 8192.0, 'gamma': 0.5}
# 0.71 {'C': 8192.0, 'gamma': 1.0}
# 0.71 {'C': 8192.0, 'gamma': 2.0}
# 0.71 {'C': 8192.0, 'gamma': 4.0}
# 0.71 {'C': 8192.0, 'gamma': 8.0}
# 0.71 {'C': 16384.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 16384.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 16384.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 16384.0, 'gamma': 0.000244140625}
# 0.71 {'C': 16384.0, 'gamma': 0.00048828125}
# 0.71 {'C': 16384.0, 'gamma': 0.0009765625}
# 0.71 {'C': 16384.0, 'gamma': 0.001953125}
# 0.71 {'C': 16384.0, 'gamma': 0.00390625}
# 0.71 {'C': 16384.0, 'gamma': 0.0078125}
# 0.71 {'C': 16384.0, 'gamma': 0.015625}
# 0.71 {'C': 16384.0, 'gamma': 0.03125}
# 0.71 {'C': 16384.0, 'gamma': 0.0625}
# 0.71 {'C': 16384.0, 'gamma': 0.125}
# 0.71 {'C': 16384.0, 'gamma': 0.25}
# 0.71 {'C': 16384.0, 'gamma': 0.5}
# 0.71 {'C': 16384.0, 'gamma': 1.0}
# 0.71 {'C': 16384.0, 'gamma': 2.0}
# 0.71 {'C': 16384.0, 'gamma': 4.0}
# 0.71 {'C': 16384.0, 'gamma': 8.0}
# 0.71 {'C': 32768.0, 'gamma': 3.0517578125e-05}
# 0.71 {'C': 32768.0, 'gamma': 6.103515625e-05}
# 0.71 {'C': 32768.0, 'gamma': 0.0001220703125}
# 0.71 {'C': 32768.0, 'gamma': 0.000244140625}
# 0.71 {'C': 32768.0, 'gamma': 0.00048828125}
# 0.71 {'C': 32768.0, 'gamma': 0.0009765625}
# 0.71 {'C': 32768.0, 'gamma': 0.001953125}
# 0.71 {'C': 32768.0, 'gamma': 0.00390625}
# 0.71 {'C': 32768.0, 'gamma': 0.0078125}
# 0.71 {'C': 32768.0, 'gamma': 0.015625}
# 0.71 {'C': 32768.0, 'gamma': 0.03125}
# 0.71 {'C': 32768.0, 'gamma': 0.0625}
# 0.71 {'C': 32768.0, 'gamma': 0.125}
# 0.71 {'C': 32768.0, 'gamma': 0.25}
# 0.71 {'C': 32768.0, 'gamma': 0.5}
# 0.71 {'C': 32768.0, 'gamma': 1.0}
# 0.71 {'C': 32768.0, 'gamma': 2.0}
# 0.71 {'C': 32768.0, 'gamma': 4.0}
# 0.71 {'C': 32768.0, 'gamma': 8.0}

# %%
#  Fitting on the training data
SVM_L = classifiers['SVM'](kernel='linear', 
                           C=grid_search_L.best_params_['C'])
SVM_L.fit(cancer_prepared, np.array(df['y']))

# Getting predictions and getting the accuracy score with confusion matrix and classification report
test_pred = SVM_L.predict(scaled_test)
test_score_SVM_L = accuracy_score(test_pred, np.array(df_test['y']))
print('The test accuracy is %0.4f'%test_score_SVM_L)
print(classification_report(test_pred, np.array(df_test['y'])))
_,test_conf_SVM_L = plot_confusion(test_pred, df_test['y'],SVM_L)
# Out:
# The test accuracy is 0.6538
#               precision    recall  f1-score   support
#
#            1       0.67      0.75      0.71         8
#            2       0.78      0.54      0.64        13
#            3       0.50      0.80      0.62         5
#
#     accuracy                           0.65        26
#    macro avg       0.65      0.70      0.65        26
# weighted avg       0.69      0.65      0.65        26

# %% [markdown]
# # 7. Support Vector Machines - RBF Kernel

# %%
param_grid = [
    {'C':2.**np.linspace(-5,15,21),'gamma':2.**np.linspace(-15,3,19)}
]

clf = SVC(kernel='rbf')

start = time()
grid_search_RBF = GridSearchCV(clf, param_grid, cv=10, n_jobs=-1)
grid_search_RBF.fit(cancer_prepared, np.array(df['y']))
print('Time take to search for the best combination si %0.6f seconds'% (time()-start))
# Out:
# Time take to search for the best combination si 8.432958 seconds
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
val_conf_SVM_RBF, val_scores_SVM_RBF, val_time_SVM_RBF = classify(cancer_prepared, np.array(df['y']),
                                                             classifiers['SVM'](kernel='rbf', 
                                                                                C=grid_search_RBF.best_params_['C'],
                                                                        gamma = grid_search_RBF.best_params_['gamma']))

print('The average training time is %0.6f seconds'%val_time_SVM_RBF.mean())
# Out:
# The model score is 0.738 (+/- 0.164)
# The IQR is 0.167 between [0.67,0.83]
# There is 0 deleted rows
#               precision    recall  f1-score   support
#
#          1.0       0.78      0.85      0.81       330
#          2.0       0.65      0.73      0.69       330
#          3.0       0.81      0.65      0.72       340
#
#     accuracy                           0.74      1000
#    macro avg       0.75      0.74      0.74      1000
# weighted avg       0.75      0.74      0.74      1000
#
# The average training time is 0.005388 seconds

# %%
#  Fitting on the training data
SVM_RBF = classifiers['SVM'](kernel='rbf', 
                           C=grid_search_RBF.best_params_['C'], 
                          gamma = grid_search_RBF.best_params_['gamma'])
SVM_RBF.fit(cancer_prepared, np.array(df['y']))

# Getting predictions and getting the accuracy score with confusion matrix and classification report
test_pred = SVM_RBF.predict(scaled_test)
test_score_SVM_RBF = accuracy_score(test_pred, np.array(df_test['y']))
print('The test accuracy is %0.4f'%test_score_SVM_RBF)
print(classification_report(test_pred, np.array(df_test['y'])))
_,test_conf_SVM_L = plot_confusion(test_pred, df_test['y'],SVM_RBF)
# Out:
# The test accuracy is 0.6538
#               precision    recall  f1-score   support
#
#            1       0.78      0.70      0.74        10
#            2       0.67      0.55      0.60        11
#            3       0.50      0.80      0.62         5
#
#     accuracy                           0.65        26
#    macro avg       0.65      0.68      0.65        26
# weighted avg       0.68      0.65      0.66        26

# %%
sns.set(font_scale=1.5)
sns.set_style('ticks')
median_prop = dict(color='g', linewidth = 1.5)
fig = plt.figure(figsize=(12,8))
fig.suptitle('LSVT Dataset')
ax = fig.add_subplot(111)
method_labels = ['NB','LR','RF','Ada','KNN','SVM_linear','SVM_RBF']
test_results = [test_score_NB, test_score_LR, test_score_RF, test_score_Ada, 
                test_score_KNN, test_score_SVM_L, test_score_SVM_RBF]
plt.boxplot([val_scores_NB, val_scores_LR, val_scores_RF, val_scores_Ada, 
             val_scores_KNN, val_scores_SVM_L_opt, val_scores_SVM_RBF], medianprops = median_prop)
ax.set_xticklabels(method_labels)
plt.scatter(x=range(1,8), y=test_results, color='r', label='Test Set Accuracy')
ax.legend(frameon=True, edgecolor='black', loc='lower right')
# ax.set_ylim([0.4,1])
ax.set_ylabel('Accuracy', fontsize = 16)
ax.set_xlabel('Classifier', fontsize = 16)
plt.show()

# %%
test_results
# Out:
# [0.3076923076923077,
#  0.7307692307692307,
#  0.5769230769230769,
#  0.5,
#  0.38461538461538464,
#  0.6538461538461539,
#  0.6538461538461539]

# %%
val_results = [val_scores_NB.mean(), val_scores_LR.mean(), val_scores_RF.mean(), val_scores_Ada.mean(), 
             val_scores_KNN.mean(), val_scores_SVM_L_opt.mean(), val_scores_SVM_RBF.mean()]

# %%
val_results
# Out:
# [0.495,
#  0.7788888888888887,
#  0.6876666666666666,
#  0.5661111111111111,
#  0.6677777777777776,
#  0.7288888888888887,
#  0.7383333333333332]

# %%
val_lsvt = [val_scores_NB, val_scores_LR, val_scores_RF, val_scores_Ada, 
             val_scores_KNN, val_scores_SVM_L_opt, val_scores_SVM_RBF]
# %store val_lsvt
# Out:
# Stored 'val_lsvt' (list)
